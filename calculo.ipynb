# %%
f(x)=(x^2+2*x-8)/(x-2)  # Definimos la función
lim(f,x=2)  # Calculamos el límite
# Out:
# x |--> 6

# %%
#aqui lo compruebo graficamente
f(x)=(x^2+2*x-8)/(x-2)  # Definimos la función
f(1,99999999999999999999999)
plot(f,figsize=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
lim(sec(x),x=pi/2,dir='+')  # Calculamos el límite  por la derecha
# Out:
# -Infinity

# %%
lim(sec(x),x=pi/2,dir='-')   # Calculamos el límite por la izquierda
# Out:
# +Infinity

# %%
diff(x^2*e^(3*x)*cos(2*x))
# Out:
# 3*x^2*cos(2*x)*e^(3*x) - 2*x^2*e^(3*x)*sin(2*x) + 2*x*cos(2*x)*e^(3*x)

# %%
f(t)=(t^2+1)/(t-2)
diff(f(t),t)
# Out:
# 2*t/(t - 2) - (t^2 + 1)/(t - 2)^2

# %%
y=var('y')
f(x)=x*cos(x)
diff(f(x),y)
# Out:
# 0

# %%
integrate((x+1)/(x^2+2*x+1),x)
# Out:
# 1/2*log(x^2 + 2*x + 1)

# %%
integrate(sec(x),x,-pi/4,pi/4)
# Out:
# log(1/2*sqrt(2) + 1) - log(-1/2*sqrt(2) + 1)

# %%
integrate(x*e^(-x**2),x)
# Out:
# -1/2*e^(-x^2)
